# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0,1,2,3])
y = np.array([3,7,4,8])

plt.plot(x,y, color="k")
plt.show()

# %%
plt.scatter(x, y, color="r")
plt.show()

# %%
x = np.linspace(-5,5,300)
y = x**2 # broadcast

plt.plot(x, y, color="r")
plt.show()

# %%
x = np.linspace(-5, 5, 300)
y1 = x**2
y2 = (x-2)**2

plt.plot(x, y1, color="r")
plt.plot(x, y2, color="g", linestyle="--")

plt.show()

# %%
#np.random.seed(0)
result = []

for _ in range(1000):
    result.append(np.random.randint(1,7, size=10).sum()) # 10回振った目の合計
    
plt.hist(result, 20, color="gray") # 第２引数はビンと呼ばれる分類区間の数を示す
plt.show()

# %%
x = np.linspace(-5, 5, 300)
sin_x = np.sin(x)
cos_x = np.cos(x)

fig, axes = plt.subplots(3,1) #2行1列でプロット
axes[0].set_ylim([-1.5, 1.5]) 
axes[1].set_ylim([-1.5, 1.5])

axes[0].plot(x, sin_x, color="r")
axes[1].plot(x, cos_x, color="k")
axes[2].plot(x, sin_x*cos_x, color="g")

plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(x, x**2, color="r")
plt.show()

# %%
def f(x,y):
    return x**2 + y**2 /4

x = np.linspace(-5,5,300)
y = np.linspace(-5,5,300)

xmesh, ymesh = np.meshgrid(x, y)

z = f(xmesh.ravel(), ymesh.ravel()).reshape(xmesh.shape)

plt.contour(x, y, z, colors="k", levels=[1,2,3,4,5])
plt.show()

# %%
x = np.array([1,2,3])
y = np.array([4,5,6])
xmesh, ymesh = np.meshgrid(x, y)

print(xmesh)
print(ymesh)
# Out:
# [[1 2 3]
#  [1 2 3]
#  [1 2 3]]
# [[4 4 4]
#  [5 5 5]
#  [6 6 6]]

# %%
x = np.linspace(-5, 5, 300)
y = np.linspace(-5, 5, 300)
xmesh, ymesh = np.meshgrid(x, y)
z = f(xmesh, ymesh)

colors = ["0.1", "0.3", "0.5", "0.7"]
levels = [1,2,3,4,5]
plt.contourf(x, y, z, colors=colors, levels=levels)
plt.show()
